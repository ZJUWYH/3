# %%
from RUL_part import *

# %%
#initial
set_seed(6194)
w_k=np.random.rand(8,1)
pi_k=0.5
mu_mk=np.random.rand(3,1)
Sigma_mk=generate_rand_psd(3)
sigma_mk_2=np.random.random(size=None)


set_seed(613)
w_j=np.random.rand(8,1)
pi_j=0.5
# mu_mj=np.random.rand(3,1)
mu_mj = np.zeros((3,1))
Sigma_mj=generate_rand_psd(3)
# Sigma_mj = np.identity(3)/100
sigma_mj_2=np.random.random(size=None)

args_a = [[pi_k,w_k,[mu_mk,Sigma_mk,sigma_mk_2],
                               [mu_mk,Sigma_mk,sigma_mk_2],[mu_mk,Sigma_mk,sigma_mk_2],[mu_mk,Sigma_mk,sigma_mk_2],
                              [mu_mk,Sigma_mk,sigma_mk_2],[mu_mk,Sigma_mk,sigma_mk_2],[mu_mk,Sigma_mk,sigma_mk_2],
                               [mu_mk,Sigma_mk,sigma_mk_2],[mu_mk,Sigma_mk,sigma_mk_2]]]
args_b = [[pi_j,w_j,[mu_mj,Sigma_mj,sigma_mj_2],
                               [mu_mj,Sigma_mj,sigma_mj_2],[mu_mj,Sigma_mj,sigma_mj_2],[mu_mj,Sigma_mj,sigma_mj_2],
                              [mu_mj,Sigma_mj,sigma_mj_2],[mu_mj,Sigma_mj,sigma_mj_2],[mu_mj,Sigma_mj,sigma_mj_2],
                               [mu_mj,Sigma_mj,sigma_mj_2],[mu_mj,Sigma_mj,sigma_mj_2]]]


args = [[pi_k,w_k,[mu_mk,Sigma_mk,sigma_mk_2],
                               [mu_mk,Sigma_mk,sigma_mk_2],[mu_mk,Sigma_mk,sigma_mk_2],[mu_mk,Sigma_mk,sigma_mk_2],
                              [mu_mk,Sigma_mk,sigma_mk_2],[mu_mk,Sigma_mk,sigma_mk_2],[mu_mk,Sigma_mk,sigma_mk_2],
         [mu_mk,Sigma_mk,sigma_mk_2],[mu_mk,Sigma_mk,sigma_mk_2]],
                                 [pi_j,w_j,[mu_mj,Sigma_mj,sigma_mj_2],
                               [mu_mj,Sigma_mj,sigma_mj_2],[mu_mj,Sigma_mj,sigma_mj_2],[mu_mj,Sigma_mj,sigma_mj_2],
                                  [mu_mj,Sigma_mj,sigma_mj_2],[mu_mj,Sigma_mj,sigma_mj_2],
                              [mu_mj,Sigma_mj,sigma_mj_2],[mu_mj,Sigma_mj,sigma_mj_2],[mu_mj,Sigma_mj,sigma_mj_2]]]

# %% [markdown]
# # only mode a

# %%
result_args_a = EM_iteration(train_dataset_mode_a,[1],100, 
                             0.1, *args_a)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 56/56 [00:04<00:00, 12.68it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 56/56 [00:05<00:00, 10.56it/s]
# iteration:1,loss:3.4099450520439207
# 100%|██████████████████████████████████████████████████████████████████████████████████| 56/56 [00:05<00:00, 10.79it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 56/56 [00:04<00:00, 12.98it/s]
# iteration:2,loss:0.2574280871344279
# 100%|██████████████████████████████████████████████████████████████████████████████████| 56/56 [00:08<00:00,  6.81it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 56/56 [00:05<00:00, 10.88it/s]
# Done! iteration:3,loss:0.04732661910099866

# %%
RUL_a_hat = get_RUL(test_dataset_mode_a,[1],*result_args_a)
RUL_a_hat
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 55/55 [00:20<00:00,  2.69it/s]
# array([100, 232, 263, 106, 118,  70, 226, 164, 212, 194,  28, 254, 120,
#         16, 214, 174, 173, 213, 140,  92, 417, 291,  41, 216, 106, 223,
#        222, 114,  20, 172, 174, 191, 225,  72, 186, 201,  83,  71, 229,
#        354, 196, 500, 168, 154,  30,  49, 311, 166,  51, 114, 239,  96,
#        193, 253,  59])

# %%
RUL_a = RUL[index_a]
RUL_a
# Out:
# array([ 51, 120,  99,  71,  55,  55,  66,  77, 115, 115,  31,  85,  58,
#         11, 144, 124,  79,  55,  71,  65, 137, 145,  22, 115,  69, 111,
#        137,  55,  11,  78, 120,  87,  87,  55,  93,  88,  40,  49, 128,
#        115,  87, 100,  63,  99,  27,  18, 145, 104,  25,  68, 144,  51,
#         81, 123,  17], dtype=int64)

# %%
sum(abs(RUL_a-RUL_a_hat))
# Out:
# 4861

# %% [markdown]
# # only mode b

# %%
result_args_b = EM_iteration(train_dataset_mode_b,[1],100, 0.1, *args_b)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 44/44 [00:06<00:00,  6.97it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 44/44 [00:06<00:00,  7.31it/s]
# iteration:1,loss:3.4665199278840317
# 100%|██████████████████████████████████████████████████████████████████████████████████| 44/44 [00:05<00:00,  8.20it/s]
#  82%|███████████████████████████████████████████████████████████████████               | 36/44 [00:04<00:01,  7.27it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ceb336a1bce7> in <module>
# ----> 1 result_args_b = EM_iteration(train_dataset_mode_b,[1],100, 0.1, *args_b)
#
# ~\Documents\yh.wang\3\EM_part.py in EM_iteration(instance, Dk_list, iteration, limitation, *args)
#     289         args_new_w = repack_para(pi_list, w_list_new, mu_list, Sigma_list, sigma_2_list)
#     290         # update other
# --> 291         pi_list_new, mu_list_new, Sigma_list_new, sigma_2_list_new = get_new_para(instance, *args_new_w)
#     292         # pi_list_new = get_hat_pi_k(instance,*args_new_w)
#     293         args_new_all = repack_para(pi_list_new, w_list_new, mu_list_new, Sigma_list_new, sigma_2_list_new)
#
# ~\Documents\yh.wang\3\EM_part.py in get_new_para(instance, *args)
#     150         for l in tqdm(range(len(instance))):
#     151             n_l = len(instance[l]["input"])
# --> 152             hat_rho_lk = get_hat_rho_l(instance[l], *args)[idx]
#     153             Phi_l = instance[l]["Phi_l"]
#     154             x_l = instance[l]["input"]
#
# ~\Documents\yh.wang\3\EM_part.py in get_hat_rho_l(instance_l, *args)
#      66     ln_numerator_list = []
#      67     for idx in range(num_mode):
# ---> 68         ln_numerator_list.append(ln_get_hat_rho_lk_numerator(instance_l, *args[idx]))
#      69     sorted_list = np.sort(ln_numerator_list)[::-1]
#      70     if np.abs(sorted_list[0] - sorted_list[-1]) > CFG.hat_rho_control:
#
# ~\Documents\yh.wang\3\EM_part.py in ln_get_hat_rho_lk_numerator(instance_l, *args)
#      54         # print(ln_get_hat_rho_lk_numerator_m(x_lm,Phi_l,*args_m))
#      55         x_lm = instance_l[name]
# ---> 56         sum_lk += ln_get_hat_rho_lk_numerator_m(x_lm, Phi_l, *args_m)
#      57     # 再加上HI的对数
#      58     sum_lk += ln_get_hat_rho_lk_numerator_m(x_l @ w_k, Phi_l, *args[-1])
#
# ~\Documents\yh.wang\3\EM_part.py in ln_get_hat_rho_lk_numerator_m(x_lm, Phi_l, *args)
#      35     mean = Phi_l @ mu_mk
#      36     var = Phi_l @ Sigma_mk @ Phi_l.T + sigma_mk_2 * np.identity(d)
# ---> 37     ln_reg_part = (-1 / 2) * (d * np.log(2 * np.pi) + np.linalg.slogdet(var)[1])
#      38     exp_part = (x_lm - mean).T @ var @ (x_lm - mean) / (-2)
#      39     return (ln_reg_part + exp_part).item()
#
# <__array_function__ internals> in slogdet(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in slogdet(a)
#    2097     real_t = _realType(result_t)
#    2098     signature = 'D->Dd' if isComplexType(t) else 'd->dd'
# -> 2099     sign, logdet = _umath_linalg.slogdet(a, signature=signature)
#    2100     sign = sign.astype(result_t, copy=False)
#    2101     logdet = logdet.astype(real_t, copy=False)
#
# KeyboardInterrupt:

# %%
RUL_b_hat = get_RUL(test_dataset_mode_b,[1],*result_args_b)
RUL_b_hat

# %%
RUL_b = RUL[index_b]
RUL_b

# %%
sum(abs(RUL_b-RUL_b_hat))

# %% [markdown]
# # all

# %%
args_all = result_args_a+result_args_b

# %%
args_all[0][0]=0.53
args_all[1][0]=0.47

# %%
# result_args = EM_iteration(train_dataset,[1,1],100, 0.1, *args_all)
result_args = EM_iteration(train_dataset,[1,1],100, 0.1, *args)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:22<00:00,  4.36it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:26<00:00,  3.84it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:19<00:00,  5.17it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:16<00:00,  5.90it/s]
# iteration:1,loss:3.447648400731029
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:15<00:00,  6.33it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:16<00:00,  6.15it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:15<00:00,  6.59it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:28<00:00,  3.46it/s]
# iteration:2,loss:2.3670663764001656
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:17<00:00,  5.77it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:14<00:00,  6.81it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:14<00:00,  6.74it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:15<00:00,  6.66it/s]
# iteration:3,loss:2.3640570402152816
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:14<00:00,  7.05it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:14<00:00,  6.79it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:16<00:00,  5.95it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:16<00:00,  6.24it/s]
# iteration:4,loss:1.5364755504703869
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:14<00:00,  6.88it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:15<00:00,  6.62it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:14<00:00,  6.99it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:14<00:00,  6.70it/s]
# iteration:5,loss:1.1182249642271778
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.54it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.11it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.67it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.53it/s]
# iteration:6,loss:0.6453959280290426
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 13.07it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.36it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.17it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.62it/s]
# iteration:7,loss:0.4942704846598157
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.20it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.58it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.72it/s]
# iteration:8,loss:0.3825729657182309
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.44it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 13.06it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.61it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.91it/s]
# iteration:9,loss:0.30131388486798627
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.92it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.61it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.41it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.85it/s]
# iteration:10,loss:0.2413320876089962
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 13.02it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 13.20it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.61it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.49it/s]
# iteration:11,loss:0.19897312668290013
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 13.01it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.12it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.75it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.78it/s]
# iteration:12,loss:0.1706042339423868
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.57it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 13.09it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.86it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.49it/s]
# iteration:13,loss:0.15199776365962592
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.93it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.79it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.23it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.30it/s]
# iteration:14,loss:0.13953344841516052
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.90it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.33it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.43it/s]
# iteration:15,loss:0.13075796972120662
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:09<00:00, 10.63it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:11<00:00,  9.00it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:15<00:00,  6.30it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:09<00:00, 10.18it/s]
# iteration:16,loss:0.12422521757838421
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:09<00:00, 10.69it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.72it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:09<00:00, 10.46it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.80it/s]
# iteration:17,loss:0.11912926120548507
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:12<00:00,  7.88it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:10<00:00,  9.59it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.56it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.78it/s]
# iteration:18,loss:0.11501571582065478
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.67it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 12.34it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 12.83it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 13.00it/s]
# Done! iteration:19,loss:0.11161407961344413

# %%
result_args
# Out:
# [[0.44,
#   array([[-0.02508065],
#          [ 0.09575333],
#          [ 0.27338721],
#          [ 0.09896038],
#          [ 0.19479786],
#          [ 0.04300773]]),
#   [array([[ 0.72499137],
#           [-1.02539741],
#           [ 4.40951562]]),
#    array([[ 0.04179118, -0.02421908, -0.14481797],
#           [-0.02421908,  0.18654081, -0.41949382],
#           [-0.14481797, -0.41949382,  4.35712958]]),
#    0.0816514819465024],
#   [array([[ 0.66981513],
#           [-0.84919019],
#           [ 4.52790925]]),
#    array([[ 0.04780613,  0.02586618, -0.19561599],
#           [ 0.02586618,  0.05484932, -0.28162375],
#           [-0.19561599, -0.28162375,  4.65160798]]),
#    0.09073206683410939],
#   [array([[ 0.43250104],
#           [-1.57763799],
#           [ 6.58755372]]),
#    array([[ 0.0482026 , -0.05787824, -0.20423986],
#           [-0.05787824,  0.60080199, -1.8793284 ],
#           [-0.20423986, -1.8793284 , 12.46804752]]),
#    0.0741279388699315],
#   [array([[-0.13057304],
#           [-1.01424122],
#           [ 7.17544533]]),
#    array([[ 0.10041947, -0.10450168, -0.28184245],
#           [-0.10450168,  0.4926106 , -1.34327032],
#           [-0.28184245, -1.34327032, 19.66812612]]),
#    0.018989116494734594],
#   [array([[ 0.35216804],
#           [-1.6463936 ],
#           [ 7.12810481]]),
#    array([[ 0.04790878, -0.06801249, -0.0565589 ],
#           [-0.06801249,  0.84260386, -2.47405096],
#           [-0.0565589 , -2.47405096, 14.93829684]]),
#    0.061805516563573595],
#   [array([[-0.19967442],
#           [-1.05191878],
#           [ 7.49019262]]),
#    array([[ 0.09067608, -0.09380184, -0.39730802],
#           [-0.09380184,  0.41234615, -1.12871677],
#           [-0.39730802, -1.12871677, 20.7013747 ]]),
#    0.016434941889457287],
#   [array([[ 0.21704858],
#           [-0.99274661],
#           [ 4.67937166]]),
#    array([[ 0.00828075,  0.0073662 , -0.09419675],
#           [ 0.0073662 ,  0.14334586, -0.73879646],
#           [-0.09419675, -0.73879646,  6.14136347]]),
#    0.009410969225563478]],
#  [0.56,
#   array([[ 0.12336278],
#          [ 0.06601853],
#          [ 0.1367002 ],
#          [-0.10489446],
#          [ 0.1884198 ],
#          [-0.05232273]]),
#   [array([[ 0.79076819],
#           [-0.35332051],
#           [ 5.72204196]]),
#    array([[ 0.12207903, -0.04423443, -0.29325209],
#           [-0.04423443,  0.09738507,  0.18651491],
#           [-0.29325209,  0.18651491,  3.21176209]]),
#    0.06566436018014259],
#   [array([[0.77739828],
#           [0.25343491],
#           [3.62242777]]),
#    array([[ 0.11013937, -0.05326356, -0.30017755],
#           [-0.05326356,  0.15910868,  0.25538276],
#           [-0.30017755,  0.25538276,  1.0817262 ]]),
#    0.06525601924046663],
#   [array([[ 0.58281432],
#           [-0.39882591],
#           [ 7.05885076]]),
#    array([[ 0.10203757, -0.04733224, -0.3337196 ],
#           [-0.04733224,  0.22271977, -0.35774104],
#           [-0.3337196 , -0.35774104,  6.80504659]]),
#    0.04459018013466003],
#   [array([[-0.46273802],
#           [ 0.3747617 ],
#           [-7.59881613]]),
#    array([[ 0.05830832, -0.04326156, -0.10431368],
#           [-0.04326156,  0.18996514, -0.82981965],
#           [-0.10431368, -0.82981965, 12.40274523]]),
#    0.06430563025017616],
#   [array([[ 0.49594079],
#           [-0.50652249],
#           [ 7.6535416 ]]),
#    array([[ 0.0939481 , -0.03368485, -0.30953273],
#           [-0.03368485,  0.22178833, -0.60821736],
#           [-0.30953273, -0.60821736,  8.6475891 ]]),
#    0.035360919036881974],
#   [array([[-0.31371752],
#           [ 0.19873708],
#           [-7.92646617]]),
#    array([[ 0.05607803, -0.04594526, -0.17878395],
#           [-0.04594526,  0.14220309, -0.75429438],
#           [-0.17878395, -0.75429438, 14.23920664]]),
#    0.06319180740001869],
#   [array([[ 0.39161526],
#           [-0.33548006],
#           [ 4.91018926]]),
#    array([[ 0.01968375,  0.00438508, -0.09409441],
#           [ 0.00438508,  0.04789644, -0.21573058],
#           [-0.09409441, -0.21573058,  3.35813392]]),
#    0.0044753084953377716]]]

# %%
args_all
# Out:
# [[0.53,
#   array([[ 0.09774845],
#          [ 0.00154834],
#          [ 0.01536099],
#          [ 0.0204939 ],
#          [ 0.19851249],
#          [ 0.02086604],
#          [-0.18905703],
#          [-0.20694628]]),
#   [array([[ 0.78071643],
#           [-0.17776129],
#           [ 5.3222943 ]]),
#    array([[ 0.12271128, -0.03983287, -0.31243007],
#           [-0.03983287,  0.09155195,  0.23232518],
#           [-0.31243007,  0.23232518,  2.69189538]]),
#    0.06575182596429381],
#   [array([[ 0.80783969],
#           [-0.1687319 ],
#           [ 4.79740217]]),
#    array([[ 0.1016782 ,  0.01526602, -0.46443151],
#           [ 0.01526602,  0.10592767, -0.0879784 ],
#           [-0.46443151, -0.0879784 ,  3.54604463]]),
#    0.06477785192476086],
#   [array([[ 0.57595759],
#           [-0.23537388],
#           [ 6.6959346 ]]),
#    array([[ 0.10302579, -0.04777478, -0.35233898],
#           [-0.04777478,  0.0846105 ,  0.05417606],
#           [-0.35233898,  0.05417606,  5.27567292]]),
#    0.044670812276496163],
#   [array([[-0.45606489],
#           [ 0.18136395],
#           [-7.22665633]]),
#    array([[ 0.05493977, -0.02977538, -0.22192888],
#           [-0.02977538,  0.12644144,  0.09635917],
#           [-0.22192888,  0.09635917,  5.48417764]]),
#    0.06436640383998547],
#   [array([[ 0.49278099],
#           [-0.40220165],
#           [ 7.44826152]]),
#    array([[ 0.09475844, -0.0345679 , -0.32160267],
#           [-0.0345679 ,  0.09001078, -0.26100848],
#           [-0.32160267, -0.26100848,  7.40781281]]),
#    0.03540816727763021],
#   [array([[-0.2857215 ],
#           [-0.27478285],
#           [-6.78875282]]),
#    array([[ 0.05531207, -0.04520066, -0.26411524],
#           [-0.04520066,  0.14764116,  0.58320224],
#           [-0.26411524,  0.58320224,  3.879754  ]]),
#    0.06345004077454404],
#   [array([[-0.55155526],
#           [-0.10485069],
#           [-5.80749883]]),
#    array([[ 0.09040808, -0.05972022, -0.33907034],
#           [-0.05972022,  0.16251983,  0.38346001],
#           [-0.33907034,  0.38346001,  2.90354419]]),
#    0.08161093515162147],
#   [array([[-0.59635452],
#           [-0.0960095 ],
#           [-5.58101793]]),
#    array([[ 0.0690415 , -0.01366052, -0.31430107],
#           [-0.01366052,  0.09892934,  0.19291962],
#           [-0.31430107,  0.19291962,  2.99511989]]),
#    0.07784544164299882],
#   [array([[ 0.41470288],
#           [-0.32988661],
#           [ 4.81774509]]),
#    array([[ 0.0182028 , -0.00466747, -0.07427244],
#           [-0.00466747,  0.04901468, -0.20576133],
#           [-0.07427244, -0.20576133,  3.00615528]]),
#    0.008596950386776651]],
#  [0.47,
#   array([[ 0.00658896],
#          [ 0.05851719],
#          [ 0.29562063],
#          [-0.13030389],
#          [ 0.15065571],
#          [ 0.11629263],
#          [ 0.10417185],
#          [ 0.07416877]]),
#   [array([[ 0.71960674],
#           [-0.9561648 ],
#           [ 4.25449284]]),
#    array([[ 0.04223949, -0.02526482, -0.15039412],
#           [-0.02526482,  0.138441  , -0.20102388],
#           [-0.15039412, -0.20102388,  3.59685239]]),
#    0.08172262925637151],
#   [array([[ 0.66187765],
#           [-0.75519074],
#           [ 4.32928951]]),
#    array([[ 0.04965693,  0.01600572, -0.18778076],
#           [ 0.01600572,  0.03937864, -0.08272724],
#           [-0.18778076, -0.08272724,  3.81412016]]),
#    0.09081077713402232],
#   [array([[ 0.43071655],
#           [-1.55413773],
#           [ 6.53394092]]),
#    array([[ 0.0482111 , -0.05603396, -0.21318619],
#           [-0.05603396,  0.54685665, -1.68945928],
#           [-0.21318619, -1.68945928, 11.87528246]]),
#    0.07414591677426277],
#   [array([[-0.13057305],
#           [-1.01424109],
#           [ 7.17544506]]),
#    array([[ 0.10041947, -0.10450164, -0.28184257],
#           [-0.10450164,  0.49260976, -1.34326813],
#           [-0.28184257, -1.34326813, 19.66812041]]),
#    0.01898911660714771],
#   [array([[ 0.35213486],
#           [-1.64593882],
#           [ 7.12702585]]),
#    array([[ 0.04790274, -0.06790291, -0.05691804],
#           [-0.06790291,  0.84066099, -2.46801682],
#           [-0.05691804, -2.46801682, 14.92060414]]),
#    0.06180589756646107],
#   [array([[-0.19967444],
#           [-1.05191852],
#           [ 7.49019203]]),
#    array([[ 0.09067608, -0.09380183, -0.39730812],
#           [-0.09380183,  0.41234533, -1.12871391],
#           [-0.39730812, -1.12871391, 20.70136588]]),
#    0.016434942006597345],
#   [array([[ 0.65343824],
#           [-0.78768995],
#           [ 4.17442004]]),
#    array([[ 0.06847426, -0.03836424,  0.08696669],
#           [-0.03836424,  0.23554552, -0.55291149],
#           [ 0.08696669, -0.55291149,  7.44051377]]),
#    0.06851150885588185],
#   [array([[ 0.65277846],
#           [-0.86139943],
#           [ 4.47501184]]),
#    array([[ 0.10361672, -0.01625981, -0.04894287],
#           [-0.01625981,  0.34500262, -1.24626677],
#           [-0.04894287, -1.24626677, 10.26127054]]),
#    0.06707791569433509],
#   [array([[ 0.34053164],
#           [-0.94622792],
#           [ 4.16452229]]),
#    array([[ 7.87978969e-03,  8.49079311e-05, -6.50497405e-02],
#           [ 8.49079311e-05,  1.44391358e-01, -6.61823747e-01],
#           [-6.50497405e-02, -6.61823747e-01,  4.90642735e+00]]),
#    0.009889468756077291]]]

# %%
np.save('./numpy/arg_all_result041701.npy',np.array(result_args,dtype=object))

# %%
np.save('./numpy/arg_all_result041201_a.npy',np.array(result_args_a,dtype=object))
np.save('./numpy/arg_all_result041201_b.npy',np.array(result_args_b,dtype=object))

# %%
np.save('./numpy/arg_all_result041201_all.npy',np.array(args_all,dtype=object))

# %%
result_args
# Out:
# [[0.56,
#   array([[ 0.12580351],
#          [ 0.06324751],
#          [ 0.1394193 ],
#          [-0.09650666],
#          [ 0.19983812],
#          [-0.04690893]]),
#   [array([[ 0.78902664],
#           [-0.30712303],
#           [ 5.67607941]]),
#    array([[ 0.12338448, -0.04290085, -0.29972192],
#           [-0.04290085,  0.04757355,  0.23389984],
#           [-0.29972192,  0.23389984,  3.12138253]]),
#    0.06569443031426699],
#   [array([[ 0.81644837],
#           [-0.30351852],
#           [ 5.17124813]]),
#    array([[ 0.10067604,  0.02513543, -0.48273318],
#           [ 0.02513543,  0.05375883, -0.11853802],
#           [-0.48273318, -0.11853802,  4.21096023]]),
#    0.06474230782370256],
#   [array([[ 0.58140172],
#           [-0.31898886],
#           [ 6.9233023 ]]),
#    array([[ 0.10253318, -0.04261424, -0.35809987],
#           [-0.04261424,  0.0567406 , -0.01869626],
#           [-0.35809987, -0.01869626,  5.94608821]]),
#    0.044674283058454015],
#   [array([[-0.46468356],
#           [ 0.31576769],
#           [-7.59678952]]),
#    array([[ 0.0547995 , -0.02726585, -0.21529301],
#           [-0.02726585,  0.09235329, -0.05440646],
#           [-0.21529301, -0.05440646,  6.69583574]]),
#    0.06434361058988487],
#   [array([[ 0.49624122],
#           [-0.45564751],
#           [ 7.5946504 ]]),
#    array([[ 0.09459558, -0.03306871, -0.31842112],
#           [-0.03306871,  0.07932584, -0.3426495 ],
#           [-0.31842112, -0.3426495 ,  7.96523518]]),
#    0.035416172902865216],
#   [array([[-0.29794019],
#           [-0.08623004],
#           [-7.30319504]]),
#    array([[ 0.05512854, -0.0414927 , -0.2601487 ],
#           [-0.0414927 ,  0.08083279,  0.50429847],
#           [-0.2601487 ,  0.50429847,  5.05123946]]),
#    0.06332302462109314],
#   [array([[ 0.39563724],
#           [-0.31939325],
#           [ 4.89877296]]),
#    array([[ 1.98450006e-02,  2.04177573e-03, -9.41438112e-02],
#           [ 2.04177573e-03,  2.07635451e-02, -1.76536154e-01],
#           [-9.41438112e-02, -1.76536154e-01,  3.26283568e+00]]),
#    0.004537671093889084]],
#  [0.44,
#   array([[-0.02204022],
#          [ 0.08908605],
#          [ 0.27300859],
#          [ 0.08218841],
#          [ 0.19450502],
#          [ 0.06396979]]),
#   [array([[ 0.72619751],
#           [-1.07364998],
#           [ 4.44641099]]),
#    array([[ 0.04012907, -0.02508106, -0.13854927],
#           [-0.02508106,  0.16736114, -0.48044513],
#           [-0.13854927, -0.48044513,  4.52667044]]),
#    0.08165875706425717],
#   [array([[ 0.65592488],
#           [-0.74155434],
#           [ 4.26429142]]),
#    array([[ 0.0485239 ,  0.0114827 , -0.17783377],
#           [ 0.0114827 ,  0.04458619, -0.09454576],
#           [-0.17783377, -0.09454576,  3.7291392 ]]),
#    0.09081401678384646],
#   [array([[ 0.43220972],
#           [-1.6438891 ],
#           [ 6.65643848]]),
#    array([[ 0.04706397, -0.062317  , -0.19803508],
#           [-0.062317  ,  0.53555192, -1.8968577 ],
#           [-0.19803508, -1.8968577 , 12.70004255]]),
#    0.07416209552287384],
#   [array([[-0.12308758],
#           [-1.04227763],
#           [ 7.50531242]]),
#    array([[ 0.0993029 , -0.09756476, -0.38220507],
#           [-0.09756476,  0.46312307, -0.95545933],
#           [-0.38220507, -0.95545933, 15.53778745]]),
#    0.01898920402413952],
#   [array([[ 0.35003657],
#           [-1.68758296],
#           [ 7.14662741]]),
#    array([[ 0.04660474, -0.07243257, -0.04983801],
#           [-0.07243257,  0.82556493, -2.5509685 ],
#           [-0.04983801, -2.5509685 , 15.20394585]]),
#    0.06180768062387388],
#   [array([[-0.19754059],
#           [-1.07198321],
#           [ 7.82104423]]),
#    array([[ 0.0913636 , -0.09348061, -0.42773629],
#           [-0.09348061,  0.40369074, -0.90028155],
#           [-0.42773629, -0.90028155, 16.81761532]]),
#    0.01643481764224461],
#   [array([[ 0.20900141],
#           [-1.01633925],
#           [ 4.70534619]]),
#    array([[ 7.52859632e-03,  4.57242099e-03, -9.42575006e-02],
#           [ 4.57242099e-03,  1.35133756e-01, -7.59152634e-01],
#           [-9.42575006e-02, -7.59152634e-01,  6.26146906e+00]]),
#    0.009260625975921715]]]

# %%
args_all
# Out:
# [[0.53,
#   array([[ 0.09774845],
#          [ 0.00154834],
#          [ 0.01536099],
#          [ 0.0204939 ],
#          [ 0.19851249],
#          [ 0.02086604],
#          [-0.18905703],
#          [-0.20694628]]),
#   [array([[ 0.78071643],
#           [-0.17776129],
#           [ 5.3222943 ]]),
#    array([[ 0.12271128, -0.03983287, -0.31243007],
#           [-0.03983287,  0.09155195,  0.23232518],
#           [-0.31243007,  0.23232518,  2.69189538]]),
#    0.06575182596429381],
#   [array([[ 0.80783969],
#           [-0.1687319 ],
#           [ 4.79740217]]),
#    array([[ 0.1016782 ,  0.01526602, -0.46443151],
#           [ 0.01526602,  0.10592767, -0.0879784 ],
#           [-0.46443151, -0.0879784 ,  3.54604463]]),
#    0.06477785192476086],
#   [array([[ 0.57595759],
#           [-0.23537388],
#           [ 6.6959346 ]]),
#    array([[ 0.10302579, -0.04777478, -0.35233898],
#           [-0.04777478,  0.0846105 ,  0.05417606],
#           [-0.35233898,  0.05417606,  5.27567292]]),
#    0.044670812276496163],
#   [array([[-0.45606489],
#           [ 0.18136395],
#           [-7.22665633]]),
#    array([[ 0.05493977, -0.02977538, -0.22192888],
#           [-0.02977538,  0.12644144,  0.09635917],
#           [-0.22192888,  0.09635917,  5.48417764]]),
#    0.06436640383998547],
#   [array([[ 0.49278099],
#           [-0.40220165],
#           [ 7.44826152]]),
#    array([[ 0.09475844, -0.0345679 , -0.32160267],
#           [-0.0345679 ,  0.09001078, -0.26100848],
#           [-0.32160267, -0.26100848,  7.40781281]]),
#    0.03540816727763021],
#   [array([[-0.2857215 ],
#           [-0.27478285],
#           [-6.78875282]]),
#    array([[ 0.05531207, -0.04520066, -0.26411524],
#           [-0.04520066,  0.14764116,  0.58320224],
#           [-0.26411524,  0.58320224,  3.879754  ]]),
#    0.06345004077454404],
#   [array([[-0.55155526],
#           [-0.10485069],
#           [-5.80749883]]),
#    array([[ 0.09040808, -0.05972022, -0.33907034],
#           [-0.05972022,  0.16251983,  0.38346001],
#           [-0.33907034,  0.38346001,  2.90354419]]),
#    0.08161093515162147],
#   [array([[-0.59635452],
#           [-0.0960095 ],
#           [-5.58101793]]),
#    array([[ 0.0690415 , -0.01366052, -0.31430107],
#           [-0.01366052,  0.09892934,  0.19291962],
#           [-0.31430107,  0.19291962,  2.99511989]]),
#    0.07784544164299882],
#   [array([[ 0.41470288],
#           [-0.32988661],
#           [ 4.81774509]]),
#    array([[ 0.0182028 , -0.00466747, -0.07427244],
#           [-0.00466747,  0.04901468, -0.20576133],
#           [-0.07427244, -0.20576133,  3.00615528]]),
#    0.008596950386776651]],
#  [0.47,
#   array([[ 0.00658896],
#          [ 0.05851719],
#          [ 0.29562063],
#          [-0.13030389],
#          [ 0.15065571],
#          [ 0.11629263],
#          [ 0.10417185],
#          [ 0.07416877]]),
#   [array([[ 0.71960674],
#           [-0.9561648 ],
#           [ 4.25449284]]),
#    array([[ 0.04223949, -0.02526482, -0.15039412],
#           [-0.02526482,  0.138441  , -0.20102388],
#           [-0.15039412, -0.20102388,  3.59685239]]),
#    0.08172262925637151],
#   [array([[ 0.66187765],
#           [-0.75519074],
#           [ 4.32928951]]),
#    array([[ 0.04965693,  0.01600572, -0.18778076],
#           [ 0.01600572,  0.03937864, -0.08272724],
#           [-0.18778076, -0.08272724,  3.81412016]]),
#    0.09081077713402232],
#   [array([[ 0.43071655],
#           [-1.55413773],
#           [ 6.53394092]]),
#    array([[ 0.0482111 , -0.05603396, -0.21318619],
#           [-0.05603396,  0.54685665, -1.68945928],
#           [-0.21318619, -1.68945928, 11.87528246]]),
#    0.07414591677426277],
#   [array([[-0.13057305],
#           [-1.01424109],
#           [ 7.17544506]]),
#    array([[ 0.10041947, -0.10450164, -0.28184257],
#           [-0.10450164,  0.49260976, -1.34326813],
#           [-0.28184257, -1.34326813, 19.66812041]]),
#    0.01898911660714771],
#   [array([[ 0.35213486],
#           [-1.64593882],
#           [ 7.12702585]]),
#    array([[ 0.04790274, -0.06790291, -0.05691804],
#           [-0.06790291,  0.84066099, -2.46801682],
#           [-0.05691804, -2.46801682, 14.92060414]]),
#    0.06180589756646107],
#   [array([[-0.19967444],
#           [-1.05191852],
#           [ 7.49019203]]),
#    array([[ 0.09067608, -0.09380183, -0.39730812],
#           [-0.09380183,  0.41234533, -1.12871391],
#           [-0.39730812, -1.12871391, 20.70136588]]),
#    0.016434942006597345],
#   [array([[ 0.65343824],
#           [-0.78768995],
#           [ 4.17442004]]),
#    array([[ 0.06847426, -0.03836424,  0.08696669],
#           [-0.03836424,  0.23554552, -0.55291149],
#           [ 0.08696669, -0.55291149,  7.44051377]]),
#    0.06851150885588185],
#   [array([[ 0.65277846],
#           [-0.86139943],
#           [ 4.47501184]]),
#    array([[ 0.10361672, -0.01625981, -0.04894287],
#           [-0.01625981,  0.34500262, -1.24626677],
#           [-0.04894287, -1.24626677, 10.26127054]]),
#    0.06707791569433509],
#   [array([[ 0.34053164],
#           [-0.94622792],
#           [ 4.16452229]]),
#    array([[ 7.87978969e-03,  8.49079311e-05, -6.50497405e-02],
#           [ 8.49079311e-05,  1.44391358e-01, -6.61823747e-01],
#           [-6.50497405e-02, -6.61823747e-01,  4.90642735e+00]]),
#    0.009889468756077291]]]

# %%
np.mean(pack_para(*args_all)[2],axis=1),np.mean(pack_para(*args_all)[3],axis=1)
# Out:
# (array([[[ 0.13136682],
#          [-0.17869271],
#          [ 0.40863464]],
#
#         [[ 0.38675963],
#          [-1.06365656],
#          [ 5.52492671]]]),
#  array([[[ 0.07889755, -0.02888153, -0.29605458],
#          [-0.02888153,  0.10629415,  0.10974379],
#          [-0.29605458,  0.10974379,  4.13224186]],
#
#         [[ 0.06211962, -0.04289318, -0.14605064],
#          [-0.04289318,  0.35502576, -1.04157903],
#          [-0.14605064, -1.04157903, 10.79828412]]]))

# %%
pack_para(*args_all)[2]
# Out:
# array([[[[ 0.78071643],
#          [-0.17776129],
#          [ 5.3222943 ]],
#
#         [[ 0.80783969],
#          [-0.1687319 ],
#          [ 4.79740217]],
#
#         [[ 0.57595759],
#          [-0.23537388],
#          [ 6.6959346 ]],
#
#         [[-0.45606489],
#          [ 0.18136395],
#          [-7.22665633]],
#
#         [[ 0.49278099],
#          [-0.40220165],
#          [ 7.44826152]],
#
#         [[-0.2857215 ],
#          [-0.27478285],
#          [-6.78875282]],
#
#         [[-0.55155526],
#          [-0.10485069],
#          [-5.80749883]],
#
#         [[-0.59635452],
#          [-0.0960095 ],
#          [-5.58101793]],
#
#         [[ 0.41470288],
#          [-0.32988661],
#          [ 4.81774509]]],
#
#
#        [[[ 0.71960674],
#          [-0.9561648 ],
#          [ 4.25449284]],
#
#         [[ 0.66187765],
#          [-0.75519074],
#          [ 4.32928951]],
#
#         [[ 0.43071655],
#          [-1.55413773],
#          [ 6.53394092]],
#
#         [[-0.13057305],
#          [-1.01424109],
#          [ 7.17544506]],
#
#         [[ 0.35213486],
#          [-1.64593882],
#          [ 7.12702585]],
#
#         [[-0.19967444],
#          [-1.05191852],
#          [ 7.49019203]],
#
#         [[ 0.65343824],
#          [-0.78768995],
#          [ 4.17442004]],
#
#         [[ 0.65277846],
#          [-0.86139943],
#          [ 4.47501184]],
#
#         [[ 0.34053164],
#          [-0.94622792],
#          [ 4.16452229]]]])

# %%
pack_para(*args_all)[3]
# Out:
# array([[[[ 1.22711280e-01, -3.98328745e-02, -3.12430068e-01],
#          [-3.98328745e-02,  9.15519490e-02,  2.32325182e-01],
#          [-3.12430068e-01,  2.32325182e-01,  2.69189538e+00]],
#
#         [[ 1.01678202e-01,  1.52660173e-02, -4.64431514e-01],
#          [ 1.52660173e-02,  1.05927675e-01, -8.79784041e-02],
#          [-4.64431514e-01, -8.79784041e-02,  3.54604463e+00]],
#
#         [[ 1.03025790e-01, -4.77747760e-02, -3.52338978e-01],
#          [-4.77747760e-02,  8.46104978e-02,  5.41760590e-02],
#          [-3.52338978e-01,  5.41760590e-02,  5.27567292e+00]],
#
#         [[ 5.49397653e-02, -2.97753850e-02, -2.21928876e-01],
#          [-2.97753850e-02,  1.26441438e-01,  9.63591732e-02],
#          [-2.21928876e-01,  9.63591732e-02,  5.48417764e+00]],
#
#         [[ 9.47584399e-02, -3.45678992e-02, -3.21602672e-01],
#          [-3.45678992e-02,  9.00107766e-02, -2.61008481e-01],
#          [-3.21602672e-01, -2.61008481e-01,  7.40781281e+00]],
#
#         [[ 5.53120694e-02, -4.52006635e-02, -2.64115239e-01],
#          [-4.52006635e-02,  1.47641163e-01,  5.83202242e-01],
#          [-2.64115239e-01,  5.83202242e-01,  3.87975400e+00]],
#
#         [[ 9.04080813e-02, -5.97202190e-02, -3.39070336e-01],
#          [-5.97202190e-02,  1.62519834e-01,  3.83460009e-01],
#          [-3.39070336e-01,  3.83460009e-01,  2.90354419e+00]],
#
#         [[ 6.90415009e-02, -1.36605171e-02, -3.14301070e-01],
#          [-1.36605171e-02,  9.89293355e-02,  1.92919625e-01],
#          [-3.14301070e-01,  1.92919625e-01,  2.99511989e+00]],
#
#         [[ 1.82028042e-02, -4.66746861e-03, -7.42724410e-02],
#          [-4.66746861e-03,  4.90146786e-02, -2.05761326e-01],
#          [-7.42724410e-02, -2.05761326e-01,  3.00615528e+00]]],
#
#
#        [[[ 4.22394852e-02, -2.52648220e-02, -1.50394120e-01],
#          [-2.52648220e-02,  1.38441000e-01, -2.01023884e-01],
#          [-1.50394120e-01, -2.01023884e-01,  3.59685239e+00]],
#
#         [[ 4.96569275e-02,  1.60057174e-02, -1.87780764e-01],
#          [ 1.60057174e-02,  3.93786433e-02, -8.27272362e-02],
#          [-1.87780764e-01, -8.27272362e-02,  3.81412016e+00]],
#
#         [[ 4.82111017e-02, -5.60339590e-02, -2.13186195e-01],
#          [-5.60339590e-02,  5.46856646e-01, -1.68945928e+00],
#          [-2.13186195e-01, -1.68945928e+00,  1.18752825e+01]],
#
#         [[ 1.00419473e-01, -1.04501637e-01, -2.81842575e-01],
#          [-1.04501637e-01,  4.92609760e-01, -1.34326813e+00],
#          [-2.81842575e-01, -1.34326813e+00,  1.96681204e+01]],
#
#         [[ 4.79027369e-02, -6.79029072e-02, -5.69180446e-02],
#          [-6.79029072e-02,  8.40660990e-01, -2.46801682e+00],
#          [-5.69180446e-02, -2.46801682e+00,  1.49206041e+01]],
#
#         [[ 9.06760791e-02, -9.38018322e-02, -3.97308122e-01],
#          [-9.38018322e-02,  4.12345327e-01, -1.12871391e+00],
#          [-3.97308122e-01, -1.12871391e+00,  2.07013659e+01]],
#
#         [[ 6.84742609e-02, -3.83642376e-02,  8.69666899e-02],
#          [-3.83642376e-02,  2.35545515e-01, -5.52911494e-01],
#          [ 8.69666899e-02, -5.52911494e-01,  7.44051377e+00]],
#
#         [[ 1.03616720e-01, -1.62598149e-02, -4.89428715e-02],
#          [-1.62598149e-02,  3.45002624e-01, -1.24626677e+00],
#          [-4.89428715e-02, -1.24626677e+00,  1.02612705e+01]],
#
#         [[ 7.87978969e-03,  8.49079311e-05, -6.50497405e-02],
#          [ 8.49079311e-05,  1.44391358e-01, -6.61823747e-01],
#          [-6.50497405e-02, -6.61823747e-01,  4.90642735e+00]]]])
